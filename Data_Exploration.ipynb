# %%
import numpy as np
import pandas as pd
import matplotlib as plt
# %matplotlib inline
from Data_Preparation_and_Cleaning import new_data

# %%
new_data
# Out:
#                                   Cases - cumulative total  \
# Name
# South Africa                                       2680225
# Ethiopia                                            295019
# Kenya                                               228363
# Zambia                                              204337
# Algeria                                             191171
# Nigeria                                             186635
# Botswana                                            146461
# Mozambique                                          142523
# Namibia                                             123483
# Zimbabwe                                            122487
# Ghana                                               113957
# Uganda                                               97453
# Rwanda                                               82630
# Cameroon                                             82454
# Senegal                                              71772
# ...

# %%
new_data.head()
# Out:
#               Cases - cumulative total  \
# Name
# South Africa                   2680225
# Ethiopia                        295019
# Kenya                           228363
# Zambia                          204337
# Algeria                         191171
#
#               Cases - cumulative total per 100000 population  \
# Name
# South Africa                                         4519.11
# Ethiopia                                              256.62
# Kenya                                                 424.69
# Zambia                                               1111.50
# Algeria                                               435.96
#
#               Cases - newly reported in last 7 days  \
# Name
# South Africa                                  84778
# Ethiopia                                       6231
# Kenya                                          8425
# Zambia                                         2259
# Algeria                                        4516
#
# ...

# %%
new_data.describe()
# Out:
#        Cases - cumulative total  \
# count              5.000000e+01
# mean               1.091949e+05
# std                3.773327e+05
# min                0.000000e+00
# 25%                9.625000e+03
# 50%                2.715700e+04
# 75%                8.258600e+04
# max                2.680225e+06
#
#        Cases - cumulative total per 100000 population  \
# count                                       50.000000
# mean                                      1438.295400
# std                                       3241.765269
# min                                          0.000000
# 25%                                        116.810000
# 50%                                        310.555000
# 75%                                        678.100000
# max                                      19915.200000
#
#        Cases - newly reported in last 7 days  \
# count                              50.000000
# mean                             3171.900000
# ...

# %%
new_data.loc["Kenya"]
# Out:
# Cases - cumulative total                                        228363.00
# Cases - cumulative total per 100000 population                     424.69
# Cases - newly reported in last 7 days                             8425.00
# Cases - newly reported in last 7 days per 100000 population         15.67
# Cases - newly reported in last 24 hours                           1286.00
# Deaths - cumulative total                                         4467.00
# Deaths - cumulative total per 100000 population                      8.31
# Deaths - newly reported in last 7 days                             148.00
# Deaths - newly reported in last 7 days per 100000 population         0.28
# Deaths - newly reported in last 24 hours                            32.00
# Name: Kenya, dtype: float64

# %%
list(new_data.columns)
# Out:
# ['Cases - cumulative total',
#  'Cases - cumulative total per 100000 population',
#  'Cases - newly reported in last 7 days',
#  'Cases - newly reported in last 7 days per 100000 population',
#  'Cases - newly reported in last 24 hours',
#  'Deaths - cumulative total',
#  'Deaths - cumulative total per 100000 population',
#  'Deaths - newly reported in last 7 days',
#  'Deaths - newly reported in last 7 days per 100000 population',
#  'Deaths - newly reported in last 24 hours']

# %%
new_data[["Cases - newly reported in last 7 days","Deaths - newly reported in last 7 days"]]
# Out:
#                                   Cases - newly reported in last 7 days  \
# Name
# South Africa                                                      84778
# Ethiopia                                                           6231
# Kenya                                                              8425
# Zambia                                                             2259
# Algeria                                                            4516
# Nigeria                                                            4673
# Botswana                                                           9703
# Mozambique                                                         4179
# Namibia                                                            1014
# Zimbabwe                                                           2634
# Ghana                                                              2725
# Uganda                                                              466
# ...

# %%
new_data[["Cases - newly reported in last 7 days","Deaths - newly reported in last 7 days"]].plot(figsize=(12,5))
# Out:
# <AxesSubplot:xlabel='Name'>
